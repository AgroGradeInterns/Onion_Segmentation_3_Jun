# %%
import numpy as np
import cv2
import os
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model, Model
from tensorflow.keras import layers
from tensorflow.keras.layers import Input,Conv2D,BatchNormalization,UpSampling2D,concatenate
import time
h,w = 224,224

# %%
from keras.layers import *
from keras.models import *

# %%
class Segmentation_model():
    def __init__(self,w_path):
        

        self.w_path = w_path
        self.masks =[]
        self.output_model()
      
    def SEModule(self,input, ratio, out_dim):
        # bs, c, h, w
        x = GlobalAveragePooling2D()(input)
        excitation = Dense(units=out_dim // ratio)(x)
        excitation = Activation('relu')(excitation)
        excitation = Dense(units=out_dim)(excitation)
        excitation = Activation('sigmoid')(excitation)
        excitation = Reshape((1, 1, out_dim))(excitation)
        scale = multiply([input, excitation])
        return scale   
        
    def SEUnet(self,nClasses, input_height=224, input_width=224):
        inputs = Input(shape=(input_height, input_width, 3))
        conv1 = Conv2D(16,3,activation='relu',padding='same',kernel_initializer='he_normal')(inputs)
        conv1 = BatchNormalization()(conv1)

        conv1 = Conv2D(16,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv1)
        conv1 = BatchNormalization()(conv1)

        # se
        conv1 = self.SEModule(conv1, 4, 16)

        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
        conv2 = Conv2D(32,3,activation='relu',padding='same',kernel_initializer='he_normal')(pool1)
        conv2 = BatchNormalization()(conv2)

        conv2 = Conv2D(32,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv2)
        conv2 = BatchNormalization()(conv2)

        # se
        conv2 = self.SEModule(conv2, 8, 32)

        pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
        conv3 = Conv2D(64,3,activation='relu',padding='same',kernel_initializer='he_normal')(pool2)
        conv3 = BatchNormalization()(conv3)

        conv3 = Conv2D(64,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv3)
        conv3 = BatchNormalization()(conv3)

        # se
        conv3 = self.SEModule(conv3, 8, 64)

        pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
        conv4 = Conv2D(128,3,activation='relu',padding='same',kernel_initializer='he_normal')(pool3)
        conv4 = BatchNormalization()(conv4)

        conv4 = Conv2D(128,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv4)
        conv4 = BatchNormalization()(conv4)

        # se
        conv4 = self.SEModule(conv4, 16, 128)

        pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

        conv5 = Conv2D(256,3,activation='relu',padding='same',kernel_initializer='he_normal')(pool4)
        conv5 = BatchNormalization()(conv5)
        conv5 = Conv2D(256,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv5)
        conv5 = BatchNormalization()(conv5)

        # se
        conv5 = self.SEModule(conv5, 16, 256)

        up6 = Conv2D(128,2,activation='relu',padding='same',kernel_initializer='he_normal')(UpSampling2D(size=(2,2))(conv5))
        up6 = BatchNormalization()(up6)

        merge6 = concatenate([conv4, up6], axis=3)
        conv6 = Conv2D(128,3,activation='relu',padding='same',kernel_initializer='he_normal')(merge6)
        conv6 = BatchNormalization()(conv6)

        conv6 = Conv2D(128,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv6)
        conv6 = BatchNormalization()(conv6)

        # se
        conv6 = self.SEModule(conv6, 16, 128)

        up7 = Conv2D(64,2,activation='relu',padding='same',kernel_initializer='he_normal')(UpSampling2D(size=(2,2))(conv6))
        up7 = BatchNormalization()(up7)

        merge7 = concatenate([conv3, up7], axis=3)
        conv7 = Conv2D(64,3,activation='relu',padding='same',kernel_initializer='he_normal')(merge7)
        conv7 = BatchNormalization()(conv7)

        conv7 = Conv2D(64,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv7)
        conv7 = BatchNormalization()(conv7)

        # se
        conv7 = self.SEModule(conv7, 8, 64)

        up8 = Conv2D(32,2,activation='relu',padding='same',kernel_initializer='he_normal')(UpSampling2D(size=(2,2))(conv7))
        up8 = BatchNormalization()(up8)

        merge8 = concatenate([conv2, up8], axis=3)
        conv8 = Conv2D(32,3,activation='relu',padding='same',kernel_initializer='he_normal')(merge8)
        conv8 = BatchNormalization()(conv8)

        conv8 = Conv2D(32,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv8)
        conv8 = BatchNormalization()(conv8)

        # se
        conv8 = self.SEModule(conv8, 4, 32)

        up9 = Conv2D(16,2,activation='relu',padding='same',kernel_initializer='he_normal')(UpSampling2D(size=(2,2))(conv8))
        up9 = BatchNormalization()(up9)

        merge9 = concatenate([conv1, up9], axis=3)
        conv9 = Conv2D(16,3,activation='relu',padding='same',kernel_initializer='he_normal')(merge9)
        conv9 = BatchNormalization()(conv9)

        conv9 = Conv2D(16,3,activation='relu',padding='same',kernel_initializer='he_normal')(conv9)
        conv9 = BatchNormalization()(conv9)

        # se
        conv9 = self.SEModule(conv9, 2, 16)

        conv10 = Conv2D(nClasses, (3, 3), padding='same')(conv9)
        conv10 = BatchNormalization()(conv10)

        outputHeight = Model(inputs, conv10).output_shape[1]
        outputWidth = Model(inputs, conv10).output_shape[2]

        out = (Reshape((outputHeight * outputWidth, nClasses)))(conv10)
        out = Activation('softmax')(out)

        model = Model(inputs, out)
        model.outputHeight = outputHeight
        model.outputWidth = outputWidth

        return model
    
    def output_model(self):
    
        model1 = self.SEUnet(nClasses=4)
        x = model1.get_layer(index=-3).output
        out0 = Conv2D(2, (1, 1), activation='softmax',name='Sprout')(x)
        out1 = Conv2D(2, (1, 1), activation='softmax',name='Black_smut')(x)
        out2 = Conv2D(2, (1, 1), activation='softmax',name='Rotten')(x)#Conv2D(2, (1, 1), activation='softmax',name='rotten')(x)
        out3 = Conv2D(2, (1, 1), activation='softmax',name='Background')(x)

        self.model_new = Model(inputs = model1.input,outputs = [out0,out1,out2,out3])
        self.model_new.load_weights(self.w_path)
        
    def predict(self,image):
        result = self.model_new.predict(image)
        
        return result
    
    
    def getPercentArea(self, full_mask, region_mask):

        total_area = np.dot(full_mask.flatten(), np.ones_like(full_mask.flatten()))
        region_area = np.dot(region_mask.flatten(), np.ones_like(region_mask.flatten()))

        area_percentage = (region_area/total_area)*100

        return area_percentage
    

    def get2_img(self,img_path1,img_path2):

        avg_2_img = []
        s1,s2=0,0
        l1,s1=self.getPrediction_values(img_path1)
        l2,s2=self.getPrediction_values(img_path2)
        
        
        for i,j in zip(l1,l2):
            add = i+j
            average = add/2
            avg_2_img.append(average)
            
        print(avg_2_img)
        print(max(s1,s2))
        return f'final % are {avg_2_img} and size is {(max(s1,s2))}' #.format(avg_2_img,(max(s1,s2)))
    
    
    
    
        
    def getPrediction_values(self,img_path):
        

        im = cv2.resize(img_path,(h,w))

        I = im.reshape([1,h,w,3])
        start = time.time()
        
        
        preds = self.predict(I)
        
        
        sp = np.argmax(preds[0], axis=3)
        sp = sp.reshape([h,w])
       
        bs = np.argmax(preds[1], axis=3)
        bs = bs.reshape([h,w])
        
        ro = np.argmax(preds[2], axis=3)
        ro = ro.reshape([h,w])
        
        bg = np.argmax(preds[3], axis=3)
        bg = bg.reshape([h,w])
        

#         pl = np.argmax(preds[3], axis=3)
#         pl = pl.reshape([h,w])

        im = cv2.cvtColor(im , cv2.COLOR_BGR2RGB)

       
        all_masks = [sp,bs,ro,bg]  
      
        

        
        image_2d = cv2.convertScaleAbs(bg)
        image_rgb = np.stack((image_2d,) * 3, axis=-1)
        
        
        
        t = time.time()
        gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
        ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
        print("time taken for image convertion for size detection =", (time.time() - t)*1000," milli seconds ")
        try:
        # find contours
            contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

            # fit ellipse
            ellipse = cv2.fitEllipse(contours[0])

            # calculate size
            size = min(ellipse[1]) * 0.08 #multiplier
    #         print("Object size: ye hai bro ", size)
        except:
            size=1

#         we were using binary 1 now we have changed to gray
        sprout_area = self.getPercentArea(gray, sp)#we were using binary 1 now we have changed to gray

        black_smut_area = self.getPercentArea(gray, bs)#we were using binary 1 now we have changed to gray

        rotten_area = self.getPercentArea(gray, ro)#we were using binary 1 now we have changed to gray
        
        background_area = self.getPercentArea(gray, bg) #we were using binary 1 now we have changed to gray

#         total_area = rotten_area+black_smut_area+sprout_area
        total_area = background_area

        r1,r2,r3=((sprout_area*100)/total_area),((black_smut_area*100)/total_area),((rotten_area*100)/total_area)
    
        final_percentage_features = [r1,r2,r3]
        
        return final_percentage_features,size
    
    def myfunct(self,path1,path2):
        for image in os.listdir(path1):
            img1 = cv2.imread(os.path.join(path1,image))

        for image in os.listdir(path2):
            img2 = cv2.imread(os.path.join(path2,image))    

        return self.get2_img(img1,img2)

# %%
# path1=r"C:\Users\ASUS\Desktop\22th may training\test_data_folder\error deployement image"
# path2=r"C:\Users\ASUS\Desktop\22th may training\test_data_folder\error deployement image"

# %%
path1=r"/home/agrograde/Desktop/25May_newdata_masks/code/test/img2"
path2=r"/home/agrograde/Desktop/25May_newdata_masks/code/test/img2"

# %%
# pred = Segmentation_model(w_path='/home/agrograde/Desktop/tryfor_sp_ro_bs/code/onions_defect_Seg_fullframe_seunet_rotten_sprout_loss-manipulation2_09May2023.h5')
# all_time=[]

# %%
pred = Segmentation_model(w_path="M2_Onion_seg_25th_May_25May2023.h5")
all_time=[]

# %%
## Rotten nad blacksmut
t = time.time()
pred.myfunct(path1,path2)
all_time.append((time.time() - t))
print("time taken =", (time.time() - t)*1000," milli seconds ")
# Out:
# time taken for image convertion for size detection = 0.10251998901367188  milli seconds
# time taken for image convertion for size detection = 0.125885009765625  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 424.94654655456543  milli seconds

# %%
path1=r"/home/agrograde/Desktop/test25/b3"
path2=r"/home/agrograde/Desktop/test25/b3"

# %%
## Black-smut
t = time.time()
pred.myfunct(path1,path2)
all_time.append((time.time() - t))
print("time taken =", (time.time() - t)*1000," milli seconds ")
# Out:
# time taken for image convertion for size detection = 0.13017654418945312  milli seconds
# time taken for image convertion for size detection = 0.07295608520507812  milli seconds
# [0.0, 10.698182811859546, 0.0]
# 7.325940551757813
# time taken = 87.96238899230957  milli seconds

# %%
path1=r'/home/agrograde/Desktop/25May_newdata_masks/code/test/img2'
path2=r'/home/agrograde/Desktop/25May_newdata_masks/code/test/img2'

# %%
## Rotten
t = time.time()
pred.myfunct(path1,path2)
all_time.append((time.time() - t))
print("time taken =", (time.time() - t)*1000," milli seconds ")
# Out:
# time taken for image convertion for size detection = 0.102996826171875  milli seconds
# time taken for image convertion for size detection = 0.13184547424316406  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 90.45195579528809  milli seconds

# %%
for i in range(50):
    t = time.time()
    pred.myfunct(path1,path2)
    all_time.append((time.time() - t))
    print("time taken =", (time.time() - t)*1000," milli seconds ")
# Out:
# time taken for image convertion for size detection = 0.14853477478027344  milli seconds
# time taken for image convertion for size detection = 0.07104873657226562  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 95.1688289642334  milli seconds
# time taken for image convertion for size detection = 0.10323524475097656  milli seconds
# time taken for image convertion for size detection = 0.09918212890625  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 85.02006530761719  milli seconds
# time taken for image convertion for size detection = 0.10251998901367188  milli seconds
# time taken for image convertion for size detection = 0.15115737915039062  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 87.11528778076172  milli seconds
# time taken for image convertion for size detection = 0.10418891906738281  milli seconds
# time taken for image convertion for size detection = 0.133514404296875  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 86.517333984375  milli seconds
# time taken for image convertion for size detection = 0.07009506225585938  milli seconds
# time taken for image convertion for size detection = 0.09989738464355469  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 84.03778076171875  milli seconds
# time taken for image convertion for size detection = 0.07009506225585938  milli seconds
# time taken for image convertion for size detection = 0.06961822509765625  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 88.90533447265625  milli seconds
# time taken for image convertion for size detection = 0.102996826171875  milli seconds
# time taken for image convertion for size detection = 0.1361370086669922  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 93.28389167785645  milli seconds
# time taken for image convertion for size detection = 0.14901161193847656  milli seconds
# time taken for image convertion for size detection = 0.14710426330566406  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 92.83232688903809  milli seconds
# time taken for image convertion for size detection = 0.07033348083496094  milli seconds
# time taken for image convertion for size detection = 0.10347366333007812  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 86.9288444519043  milli seconds
# time taken for image convertion for size detection = 0.14638900756835938  milli seconds
# time taken for image convertion for size detection = 0.10347366333007812  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 84.15675163269043  milli seconds
# time taken for image convertion for size detection = 0.102996826171875  milli seconds
# time taken for image convertion for size detection = 0.06985664367675781  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 83.76359939575195  milli seconds
# time taken for image convertion for size detection = 0.07009506225585938  milli seconds
# time taken for image convertion for size detection = 0.13375282287597656  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 87.07404136657715  milli seconds
# time taken for image convertion for size detection = 0.1366138458251953  milli seconds
# time taken for image convertion for size detection = 0.10228157043457031  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 89.21313285827637  milli seconds
# time taken for image convertion for size detection = 0.0705718994140625  milli seconds
# time taken for image convertion for size detection = 0.07224082946777344  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 94.02132034301758  milli seconds
# time taken for image convertion for size detection = 0.10418891906738281  milli seconds
# time taken for image convertion for size detection = 0.07128715515136719  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 86.59934997558594  milli seconds
# time taken for image convertion for size detection = 0.102996826171875  milli seconds
# time taken for image convertion for size detection = 0.13065338134765625  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 84.66935157775879  milli seconds
# time taken for image convertion for size detection = 0.11730194091796875  milli seconds
# time taken for image convertion for size detection = 0.1494884490966797  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 92.03314781188965  milli seconds
# time taken for image convertion for size detection = 0.12922286987304688  milli seconds
# time taken for image convertion for size detection = 0.10275840759277344  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 86.69495582580566  milli seconds
# time taken for image convertion for size detection = 0.1049041748046875  milli seconds
# time taken for image convertion for size detection = 0.07128715515136719  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 94.35772895812988  milli seconds
# time taken for image convertion for size detection = 0.10180473327636719  milli seconds
# time taken for image convertion for size detection = 0.14519691467285156  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 85.57653427124023  milli seconds
# time taken for image convertion for size detection = 0.12922286987304688  milli seconds
# time taken for image convertion for size detection = 0.072479248046875  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 91.95232391357422  milli seconds
# time taken for image convertion for size detection = 0.11444091796875  milli seconds
# time taken for image convertion for size detection = 0.07081031799316406  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 93.20712089538574  milli seconds
# time taken for image convertion for size detection = 0.11181831359863281  milli seconds
# time taken for image convertion for size detection = 0.07009506225585938  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 94.1920280456543  milli seconds
# time taken for image convertion for size detection = 0.10228157043457031  milli seconds
# time taken for image convertion for size detection = 0.07081031799316406  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 97.79596328735352  milli seconds
# time taken for image convertion for size detection = 0.07104873657226562  milli seconds
# time taken for image convertion for size detection = 0.12087821960449219  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 81.91871643066406  milli seconds
# time taken for image convertion for size detection = 0.102996826171875  milli seconds
# time taken for image convertion for size detection = 0.07271766662597656  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 83.40597152709961  milli seconds
# time taken for image convertion for size detection = 0.10466575622558594  milli seconds
# time taken for image convertion for size detection = 0.13327598571777344  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 93.13511848449707  milli seconds
# time taken for image convertion for size detection = 0.072479248046875  milli seconds
# time taken for image convertion for size detection = 0.1475811004638672  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 92.70524978637695  milli seconds
# time taken for image convertion for size detection = 0.10442733764648438  milli seconds
# time taken for image convertion for size detection = 0.07700920104980469  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 85.70361137390137  milli seconds
# time taken for image convertion for size detection = 0.10251998901367188  milli seconds
# time taken for image convertion for size detection = 0.10251998901367188  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 82.16691017150879  milli seconds
# time taken for image convertion for size detection = 0.072479248046875  milli seconds
# time taken for image convertion for size detection = 0.10275840759277344  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 89.35260772705078  milli seconds
# time taken for image convertion for size detection = 0.10204315185546875  milli seconds
# time taken for image convertion for size detection = 0.13971328735351562  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 83.25743675231934  milli seconds
# time taken for image convertion for size detection = 0.07128715515136719  milli seconds
# time taken for image convertion for size detection = 0.13566017150878906  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 89.23459053039551  milli seconds
# time taken for image convertion for size detection = 0.07128715515136719  milli seconds
# time taken for image convertion for size detection = 0.07033348083496094  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 84.50484275817871  milli seconds
# time taken for image convertion for size detection = 0.1010894775390625  milli seconds
# time taken for image convertion for size detection = 0.07128715515136719  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 85.64066886901855  milli seconds
# time taken for image convertion for size detection = 0.1499652862548828  milli seconds
# time taken for image convertion for size detection = 0.14710426330566406  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 94.9559211730957  milli seconds
# time taken for image convertion for size detection = 0.10251998901367188  milli seconds
# time taken for image convertion for size detection = 0.07224082946777344  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 84.54537391662598  milli seconds
# time taken for image convertion for size detection = 0.1342296600341797  milli seconds
# time taken for image convertion for size detection = 0.10275840759277344  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 94.07806396484375  milli seconds
# time taken for image convertion for size detection = 0.10156631469726562  milli seconds
# time taken for image convertion for size detection = 0.13494491577148438  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 89.10226821899414  milli seconds
# time taken for image convertion for size detection = 0.06985664367675781  milli seconds
# time taken for image convertion for size detection = 0.11610984802246094  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 89.46585655212402  milli seconds
# time taken for image convertion for size detection = 0.10061264038085938  milli seconds
# time taken for image convertion for size detection = 0.14591217041015625  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 99.71499443054199  milli seconds
# time taken for image convertion for size detection = 0.0705718994140625  milli seconds
# time taken for image convertion for size detection = 0.12969970703125  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 84.83695983886719  milli seconds
# time taken for image convertion for size detection = 0.10180473327636719  milli seconds
# time taken for image convertion for size detection = 0.13065338134765625  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 92.1030044555664  milli seconds
# time taken for image convertion for size detection = 0.10275840759277344  milli seconds
# time taken for image convertion for size detection = 0.15115737915039062  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 86.24482154846191  milli seconds
# time taken for image convertion for size detection = 0.10347366333007812  milli seconds
# time taken for image convertion for size detection = 0.1201629638671875  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 82.47780799865723  milli seconds
# time taken for image convertion for size detection = 0.16641616821289062  milli seconds
# time taken for image convertion for size detection = 0.10156631469726562  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 87.13126182556152  milli seconds
# time taken for image convertion for size detection = 0.10228157043457031  milli seconds
# time taken for image convertion for size detection = 0.072479248046875  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 83.33015441894531  milli seconds
# time taken for image convertion for size detection = 0.10395050048828125  milli seconds
# time taken for image convertion for size detection = 0.13494491577148438  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 90.46697616577148  milli seconds
# time taken for image convertion for size detection = 0.1347064971923828  milli seconds
# time taken for image convertion for size detection = 0.07224082946777344  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 84.10429954528809  milli seconds
# time taken for image convertion for size detection = 0.0705718994140625  milli seconds
# time taken for image convertion for size detection = 0.10156631469726562  milli seconds
# [0.0, 1.0813076278290026, 16.881810561609388]
# 1
# time taken = 87.4176025390625  milli seconds
